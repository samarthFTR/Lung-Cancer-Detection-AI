# %% [markdown]
# ## Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset\\cancer patient data sets.csv")
df.head()
# Out:
#    Unnamed: 0  index Patient Id  Age  Gender  Air Pollution  Alcohol use  \
# 0           0      0         P1   33       1              2            4
# 1           1      1        P10   17       1              3            1
# 2           2      2       P100   35       1              4            5
# 3           3      3      P1000   37       1              7            7
# 4           4      4       P101   46       1              6            8
#
#    Dust Allergy  OccuPational Hazards  Genetic Risk  ...  Fatigue  \
# 0             5                     4             3  ...        3
# 1             5                     3             4  ...        1
# 2             6                     5             5  ...        8
# 3             7                     7             6  ...        4
# 4             7                     7             7  ...        3
#
#    Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0            4                    2         2                      3
# 1            3                    7         8                      6
# 2            7                    9         2                      1
# 3            2                    3         1                      4
# 4            2                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Patient Id', 'Age', 'Gender', 'Air Pollution',
#        'Alcohol use', 'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
df['Patient Id'].duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# index                        int64
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# dtype: object

# %% [markdown]
# # Changing Data types

# %%
categorical_cols = [
    'Gender', 'Genetic Risk', 'Balanced Diet', 'Obesity', 'Smoking',
    'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
    'Weight Loss', 'Shortness of Breath', 'Wheezing', 'Swallowing Difficulty',
    'Clubbing of Finger Nails', 'Frequent Cold', 'Dry Cough', 'Snoring', 'Level',
    'Air Pollution', 'Alcohol use', 'Dust Allergy', 'OccuPational Hazards',
    'chronic Lung Disease'
]

df[categorical_cols] = df[categorical_cols].astype('category')

# %%
df['Gender']=df['Gender'].map({1:'Male',2:'Female'})

# %%
df.to_csv('dataset\\cancer patient data sets.csv')

# %%
df.drop("Patient Id",axis=1,inplace=True)
df_1=df.drop("Level",axis=1,inplace=False)

# %%
df_1.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring'],
#       dtype='object')

# %%
df_1.drop('Gender',axis=1,inplace=True)
sns.heatmap(df_1.corr(method="pearson"))
plt.show()

# %%
counts = df['Level'].value_counts()
plt.title("Distribution of High,Medium and Low Risk in dataset")
plt.pie(counts, labels=counts.index, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
df = pd.read_csv("dataset\\cancer patient data sets.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  index Patient Id  Age Gender  Air Pollution  \
# 0             0           0      0         P1   33   Male              2
# 1             1           1      1        P10   17   Male              3
# 2             2           2      2       P100   35   Male              4
# 3             3           3      3      P1000   37   Male              7
# 4             4           4      4       P101   46   Male              6
#
#    Alcohol use  Dust Allergy  OccuPational Hazards  ...  Fatigue  Weight Loss  \
# 0            4             5                     4  ...        3            4
# 1            1             5                     3  ...        1            3
# 2            5             6                     5  ...        8            7
# 3            7             7                     7  ...        4            2
# 4            8             7                     7  ...        3            2
#
#    Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0                    2         2                      3
# 1                    7         8                      6
# 2                    9         2                      1
# 3                    3         1                      4
# 4                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High
#
# [5 rows x 28 columns]

# %%
df.drop(columns=['Unnamed: 0.1','Unnamed: 0','index'],inplace=True)
df.head()
# Out:
#   Patient Id  Age Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33   Male              2            4             5
# 1        P10   17   Male              3            1             5
# 2       P100   35   Male              4            5             6
# 3      P1000   37   Male              7            7             7
# 4       P101   46   Male              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0  ...        3            4                    2         2
# 1  ...        1            3                    7         8
# 2  ...        8            7                    9         2
# 3  ...        4            2                    3         1
# 4  ...        3            2                    4         1
#
#    Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  Dry Cough  \
# 0                      3                         1              2          3
# 1                      6                         2              1          7
# 2                      1                         4              6          7
# 3                      4                         5              6          7
# 4                      4                         2              4          2
#
#    Snoring   Level
# 0        4     Low
# 1        2  Medium
# 2        2    High
# 3        5    High
# 4        3    High
#
# [5 rows x 25 columns]

# %%
df.to_csv('dataset\\cancer patient data sets.csv')
